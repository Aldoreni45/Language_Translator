# %%
from langchain_community.tools import GoogleCloudTextToSpeechTool

# %%
text_to_speak = "Hello world!"

tts = GoogleCloudTextToSpeechTool()
speech_file = tts.run(text_to_speak)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[3], line 3
#       1 text_to_speak = "Hello world!"
# ----> 3 tts = GoogleCloudTextToSpeechTool()
#       4 speech_file = tts.run(text_to_speak)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\_api\deprecation.py:214, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     212     warned = True
#     213     emit_warning()
# --> 214 return wrapped(self, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_community\tools\google_cloud\texttospeech.py:68, in GoogleCloudTextToSpeechTool.__init__(self, **kwargs)
#      64 texttospeech = _import_google_cloud_texttospeech()
#      66 super().__init__(**kwargs)
# ---> 68 self._client = texttospeech.TextToSpeechClient(
#      69     client_info=get_client_info(module="text-to-speech")
#      70 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\client.py:678, in TextToSpeechClient.__init__(self, credentials, transport, client_options, client_info)
#     670     transport_init: Union[
#     671         Type[TextToSpeechTransport], Callable[..., TextToSpeechTransport]
#     672     ] = (
#    (...)
#     675         else cast(Callable[..., TextToSpeechTransport], transport)
#     676     )
#     677     # initialize with the provided callable or the passed in class
# --> 678     self._transport = transport_init(
#     679         credentials=credentials,
#     680         credentials_file=self._client_options.credentials_file,
#     681         host=self._api_endpoint,
#     682         scopes=self._client_options.scopes,
#     683         client_cert_source_for_mtls=self._client_cert_source,
#     684         quota_project_id=self._client_options.quota_project_id,
#     685         client_info=client_info,
#     686         always_use_jwt_access=True,
#     687         api_audience=self._client_options.api_audience,
#     688     )
#     690 if "async" not in str(self._transport):
#     691     if CLIENT_LOGGING_SUPPORTED and _LOGGER.isEnabledFor(
#     692         std_logging.DEBUG
#     693     ):  # pragma: NO COVER
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\transports\grpc.py:234, in TextToSpeechGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     229             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     230                 certificate_chain=cert, private_key=key
#     231             )
#     233 # The base transport sets the host, credentials and scopes
# --> 234 super().__init__(
#     235     host=host,
#     236     credentials=credentials,
#     237     credentials_file=credentials_file,
#     238     scopes=scopes,
#     239     quota_project_id=quota_project_id,
#     240     client_info=client_info,
#     241     always_use_jwt_access=always_use_jwt_access,
#     242     api_audience=api_audience,
#     243 )
#     245 if not self._grpc_channel:
#     246     # initialize with the provided callable or the default channel
#     247     channel_init = channel or type(self).create_channel
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\transports\base.py:100, in TextToSpeechTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#      96     credentials, _ = google.auth.load_credentials_from_file(
#      97         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#      98     )
#      99 elif credentials is None and not self._ignore_credentials:
# --> 100     credentials, _ = google.auth.default(
#     101         **scopes_kwargs, quota_project_id=quota_project_id
#     102     )
#     103     # Don't apply audience if the credentials file passed from user.
#     104     if hasattr(credentials, "with_gdch_audience"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:697, in default(scopes, request, quota_project_id, default_scopes)
#     689             _LOGGER.warning(
#     690                 "No project ID could be determined. Consider running "
#     691                 "`gcloud config set project` or setting the %s "
#     692                 "environment variable",
#     693                 environment_vars.PROJECT,
#     694             )
#     695         return credentials, effective_project_id
# --> 697 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
from langchain_google_community import TextToSpeechTool

text_to_speak = "Hello world!"
tts = TextToSpeechTool()
speech_file = tts.run(text_to_speak)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[4], line 4
#       1 from langchain_google_community import TextToSpeechTool
#       3 text_to_speak = "Hello world!"
# ----> 4 tts = TextToSpeechTool()
#       5 speech_file = tts.run(text_to_speak)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_google_community\texttospeech.py:63, in TextToSpeechTool.__init__(self, **kwargs)
#      59 texttospeech = _import_google_cloud_texttospeech()
#      61 super().__init__(**kwargs)
# ---> 63 self._client = texttospeech.TextToSpeechClient(
#      64     client_info=get_client_info(module="text-to-speech")
#      65 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\client.py:678, in TextToSpeechClient.__init__(self, credentials, transport, client_options, client_info)
#     670     transport_init: Union[
#     671         Type[TextToSpeechTransport], Callable[..., TextToSpeechTransport]
#     672     ] = (
#    (...)
#     675         else cast(Callable[..., TextToSpeechTransport], transport)
#     676     )
#     677     # initialize with the provided callable or the passed in class
# --> 678     self._transport = transport_init(
#     679         credentials=credentials,
#     680         credentials_file=self._client_options.credentials_file,
#     681         host=self._api_endpoint,
#     682         scopes=self._client_options.scopes,
#     683         client_cert_source_for_mtls=self._client_cert_source,
#     684         quota_project_id=self._client_options.quota_project_id,
#     685         client_info=client_info,
#     686         always_use_jwt_access=True,
#     687         api_audience=self._client_options.api_audience,
#     688     )
#     690 if "async" not in str(self._transport):
#     691     if CLIENT_LOGGING_SUPPORTED and _LOGGER.isEnabledFor(
#     692         std_logging.DEBUG
#     693     ):  # pragma: NO COVER
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\transports\grpc.py:234, in TextToSpeechGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     229             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     230                 certificate_chain=cert, private_key=key
#     231             )
#     233 # The base transport sets the host, credentials and scopes
# --> 234 super().__init__(
#     235     host=host,
#     236     credentials=credentials,
#     237     credentials_file=credentials_file,
#     238     scopes=scopes,
#     239     quota_project_id=quota_project_id,
#     240     client_info=client_info,
#     241     always_use_jwt_access=always_use_jwt_access,
#     242     api_audience=api_audience,
#     243 )
#     245 if not self._grpc_channel:
#     246     # initialize with the provided callable or the default channel
#     247     channel_init = channel or type(self).create_channel
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\transports\base.py:100, in TextToSpeechTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#      96     credentials, _ = google.auth.load_credentials_from_file(
#      97         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#      98     )
#      99 elif credentials is None and not self._ignore_credentials:
# --> 100     credentials, _ = google.auth.default(
#     101         **scopes_kwargs, quota_project_id=quota_project_id
#     102     )
#     103     # Don't apply audience if the credentials file passed from user.
#     104     if hasattr(credentials, "with_gdch_audience"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:697, in default(scopes, request, quota_project_id, default_scopes)
#     689             _LOGGER.warning(
#     690                 "No project ID could be determined. Consider running "
#     691                 "`gcloud config set project` or setting the %s "
#     692                 "environment variable",
#     693                 environment_vars.PROJECT,
#     694             )
#     695         return credentials, effective_project_id
# --> 697 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
from google.cloud import texttospeech
from langchain_google_community import TextToSpeechTool

# Custom configuration
client_options = {
    'api_endpoint': 'texttospeech.googleapis.com'
}

tts = TextToSpeechTool(
    client_options=client_options,
  # Optional
)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[16], line 9
#       4 # Custom configuration
#       5 client_options = {
#       6     'api_endpoint': 'texttospeech.googleapis.com'
#       7 }
# ----> 9 tts = TextToSpeechTool(
#      10     client_options=client_options,
#      11   # Optional
#      12 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_google_community\texttospeech.py:63, in TextToSpeechTool.__init__(self, **kwargs)
#      59 texttospeech = _import_google_cloud_texttospeech()
#      61 super().__init__(**kwargs)
# ---> 63 self._client = texttospeech.TextToSpeechClient(
#      64     client_info=get_client_info(module="text-to-speech")
#      65 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\client.py:678, in TextToSpeechClient.__init__(self, credentials, transport, client_options, client_info)
#     670     transport_init: Union[
#     671         Type[TextToSpeechTransport], Callable[..., TextToSpeechTransport]
#     672     ] = (
#    (...)
#     675         else cast(Callable[..., TextToSpeechTransport], transport)
#     676     )
#     677     # initialize with the provided callable or the passed in class
# --> 678     self._transport = transport_init(
#     679         credentials=credentials,
#     680         credentials_file=self._client_options.credentials_file,
#     681         host=self._api_endpoint,
#     682         scopes=self._client_options.scopes,
#     683         client_cert_source_for_mtls=self._client_cert_source,
#     684         quota_project_id=self._client_options.quota_project_id,
#     685         client_info=client_info,
#     686         always_use_jwt_access=True,
#     687         api_audience=self._client_options.api_audience,
#     688     )
#     690 if "async" not in str(self._transport):
#     691     if CLIENT_LOGGING_SUPPORTED and _LOGGER.isEnabledFor(
#     692         std_logging.DEBUG
#     693     ):  # pragma: NO COVER
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\transports\grpc.py:234, in TextToSpeechGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     229             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     230                 certificate_chain=cert, private_key=key
#     231             )
#     233 # The base transport sets the host, credentials and scopes
# --> 234 super().__init__(
#     235     host=host,
#     236     credentials=credentials,
#     237     credentials_file=credentials_file,
#     238     scopes=scopes,
#     239     quota_project_id=quota_project_id,
#     240     client_info=client_info,
#     241     always_use_jwt_access=always_use_jwt_access,
#     242     api_audience=api_audience,
#     243 )
#     245 if not self._grpc_channel:
#     246     # initialize with the provided callable or the default channel
#     247     channel_init = channel or type(self).create_channel
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\cloud\texttospeech_v1\services\text_to_speech\transports\base.py:100, in TextToSpeechTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#      96     credentials, _ = google.auth.load_credentials_from_file(
#      97         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#      98     )
#      99 elif credentials is None and not self._ignore_credentials:
# --> 100     credentials, _ = google.auth.default(
#     101         **scopes_kwargs, quota_project_id=quota_project_id
#     102     )
#     103     # Don't apply audience if the credentials file passed from user.
#     104     if hasattr(credentials, "with_gdch_audience"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:663, in default(scopes, request, quota_project_id, default_scopes)
#     651 checkers = (
#     652     # Avoid passing scopes here to prevent passing scopes to user credentials.
#     653     # with_scopes_if_required() below will ensure scopes/default scopes are
#    (...)
#     659     lambda: _get_gce_credentials(request, quota_project_id=quota_project_id),
#     660 )
#     662 for checker in checkers:
# --> 663     credentials, project_id = checker()
#     664     if credentials is not None:
#     665         credentials = with_scopes_if_required(
#     666             credentials, scopes, default_scopes=default_scopes
#     667         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:656, in default.<locals>.<lambda>()
#     645 from google.auth.credentials import CredentialsWithQuotaProject
#     647 explicit_project_id = os.environ.get(
#     648     environment_vars.PROJECT, os.environ.get(environment_vars.LEGACY_PROJECT)
#     649 )
#     651 checkers = (
#     652     # Avoid passing scopes here to prevent passing scopes to user credentials.
#     653     # with_scopes_if_required() below will ensure scopes/default scopes are
#     654     # safely set on the returned credentials since requires_scopes will
#     655     # guard against setting scopes on user credentials.
# --> 656     lambda: _get_explicit_environ_credentials(quota_project_id=quota_project_id),
#     657     lambda: _get_gcloud_sdk_credentials(quota_project_id=quota_project_id),
#     658     _get_gae_credentials,
#     659     lambda: _get_gce_credentials(request, quota_project_id=quota_project_id),
#     660 )
#     662 for checker in checkers:
#     663     credentials, project_id = checker()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:271, in _get_explicit_environ_credentials(quota_project_id)
#     268     return _get_gcloud_sdk_credentials(quota_project_id=quota_project_id)
#     270 if explicit_file is not None:
# --> 271     credentials, project_id = load_credentials_from_file(
#     272         os.environ[environment_vars.CREDENTIALS], quota_project_id=quota_project_id
#     273     )
#     274     credentials._cred_file_path = f"{explicit_file} file via the GOOGLE_APPLICATION_CREDENTIALS environment variable"
#     276     return credentials, project_id
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\google\auth\_default.py:114, in load_credentials_from_file(filename, scopes, default_scopes, quota_project_id, request)
#      82 """Loads Google credentials from a file.
#      83
#      84 The credentials file must be a service account key, stored authorized
#    (...)
#     111         wrong format or is missing.
#     112 """
#     113 if not os.path.exists(filename):
# --> 114     raise exceptions.DefaultCredentialsError(
#     115         "File {} was not found.".format(filename)
#     116     )
#     118 with io.open(filename, "r") as file_obj:
#     119     try:
#
# DefaultCredentialsError: File /path/to/your/service-account-key.json was not found.

# %%
from gtts import gTTS
import pygame
import os

def gtts_text_to_speech(text, lang='en'):
    # Create TTS object
    tts = gTTS(text=text, lang=lang)
    
    # Save to file
    output_file = "output.mp3"
    tts.save(output_file)
    
    # Initialize pygame mixer
    pygame.mixer.init()
    
    # Load and play the audio
    pygame.mixer.music.load(output_file)
    pygame.mixer.music.play()
    
    # Wait until playback is finished
    while pygame.mixer.music.get_busy():
        pygame.time.Clock().tick(10)
    
    return output_file

# Usage
speech_file = gtts_text_to_speech("Hello world!")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[34], line 27
#      24     return output_file
#      26 # Usage
# ---> 27 speech_file = gtts_text_to_speech("Hello world!")
#
# Cell In[34], line 11, in gtts_text_to_speech(text, lang)
#       9 # Save to file
#      10 output_file = "output.mp3"
# ---> 11 tts.save(output_file)
#      13 # Initialize pygame mixer
#      14 pygame.mixer.init()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gtts\tts.py:334, in gTTS.save(self, savefile)
#     324 def save(self, savefile):
#     325     """Do the TTS API request and write result to file.
#     326
#     327     Args:
#    (...)
#     332
#     333     """
# --> 334     with open(str(savefile), "wb") as f:
#     335         self.write_to_fp(f)
#     336         f.flush()
#
# PermissionError: [Errno 13] Permission denied: 'output.mp3'

# %%
! pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 728.2 kB/s eta 0:00:14
#    - -------------------------------------- 0.5/10.6 MB 728.2 kB/s eta 0:00:14
#    -- ------------------------------------- 0.8/10.6 MB 609.6 kB/s eta 0:00:17
#    -- ------------------------------------- 0.8/10.6 MB 609.6 kB/s eta 0:00:17
#    --- ------------------------------------ 1.0/10.6 MB 578.3 kB/s eta 0:00:17
#    --- ------------------------------------ 1.0/10.6 MB 578.3 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.3/10.6 MB 593.8 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.3/10.6 MB 593.8 kB/s eta 0:00:16
#    ----- ---------------------------------- 1.6/10.6 MB 645.0 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.6/10.6 MB 645.0 kB/s eta 0:00:15
#    ------ --------------------------------- 1.8/10.6 MB 632.9 kB/s eta 0:00:14
#    ------ --------------------------------- 1.8/10.6 MB 632.9 kB/s eta 0:00:14
#    ------ --------------------------------- 1.8/10.6 MB 632.9 kB/s eta 0:00:14
#    ------- -------------------------------- 2.1/10.6 MB 605.2 kB/s eta 0:00:15
#    ------- -------------------------------- 2.1/10.6 MB 605.2 kB/s eta 0:00:15
#    -------- ------------------------------- 2.4/10.6 MB 615.5 kB/s eta 0:00:14
#    -------- ------------------------------- 2.4/10.6 MB 615.5 kB/s eta 0:00:14
#    --------- ------------------------------ 2.6/10.6 MB 611.2 kB/s eta 0:00:14
#    --------- ------------------------------ 2.6/10.6 MB 611.2 kB/s eta 0:00:14
#    --------- ------------------------------ 2.6/10.6 MB 611.2 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.9/10.6 MB 592.8 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.9/10.6 MB 592.8 kB/s eta 0:00:14
#    ----------- ---------------------------- 3.1/10.6 MB 591.5 kB/s eta 0:00:13
#    ----------- ---------------------------- 3.1/10.6 MB 591.5 kB/s eta 0:00:13
#    ------------ --------------------------- 3.4/10.6 MB 592.1 kB/s eta 0:00:13
#    ------------- -------------------------- 3.7/10.6 MB 610.8 kB/s eta 0:00:12
#    -------------- ------------------------- 3.9/10.6 MB 638.3 kB/s eta 0:00:11
#    --------------- ------------------------ 4.2/10.6 MB 664.0 kB/s eta 0:00:10
#    ---------------- ----------------------- 4.5/10.6 MB 693.6 kB/s eta 0:00:09
#    ----------------- ---------------------- 4.7/10.6 MB 704.1 kB/s eta 0:00:09
#    ----------------- ---------------------- 4.7/10.6 MB 704.1 kB/s eta 0:00:09
#    ------------------ --------------------- 5.0/10.6 MB 708.8 kB/s eta 0:00:08
#    ------------------ --------------------- 5.0/10.6 MB 708.8 kB/s eta 0:00:08
#    ------------------- -------------------- 5.2/10.6 MB 695.9 kB/s eta 0:00:08
#    ------------------- -------------------- 5.2/10.6 MB 695.9 kB/s eta 0:00:08
#    -------------------- ------------------- 5.5/10.6 MB 688.9 kB/s eta 0:00:08
#    -------------------- ------------------- 5.5/10.6 MB 688.9 kB/s eta 0:00:08
#    -------------------- ------------------- 5.5/10.6 MB 688.9 kB/s eta 0:00:08
#    --------------------- ------------------ 5.8/10.6 MB 681.4 kB/s eta 0:00:08
#    ---------------------- ----------------- 6.0/10.6 MB 686.0 kB/s eta 0:00:07
#    ---------------------- ----------------- 6.0/10.6 MB 686.0 kB/s eta 0:00:07
#    ----------------------- ---------------- 6.3/10.6 MB 692.7 kB/s eta 0:00:07
#    ------------------------ --------------- 6.6/10.6 MB 708.9 kB/s eta 0:00:06
#    ------------------------- -------------- 6.8/10.6 MB 718.2 kB/s eta 0:00:06
#    -------------------------- ------------- 7.1/10.6 MB 724.5 kB/s eta 0:00:05
#    -------------------------- ------------- 7.1/10.6 MB 724.5 kB/s eta 0:00:05
#    --------------------------- ------------ 7.3/10.6 MB 719.0 kB/s eta 0:00:05
#    --------------------------- ------------ 7.3/10.6 MB 719.0 kB/s eta 0:00:05
#    --------------------------- ------------ 7.3/10.6 MB 719.0 kB/s eta 0:00:05
#    ---------------------------- ----------- 7.6/10.6 MB 712.8 kB/s eta 0:00:05
#    ---------------------------- ----------- 7.6/10.6 MB 712.8 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.9/10.6 MB 704.1 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.9/10.6 MB 704.1 kB/s eta 0:00:04
#    ------------------------------ --------- 8.1/10.6 MB 701.0 kB/s eta 0:00:04
#    ------------------------------ --------- 8.1/10.6 MB 701.0 kB/s eta 0:00:04
#    ------------------------------- -------- 8.4/10.6 MB 696.2 kB/s eta 0:00:04
#    ------------------------------- -------- 8.4/10.6 MB 696.2 kB/s eta 0:00:04
#    ------------------------------- -------- 8.4/10.6 MB 696.2 kB/s eta 0:00:04
#    -------------------------------- ------- 8.7/10.6 MB 692.7 kB/s eta 0:00:03
#    -------------------------------- ------- 8.7/10.6 MB 692.7 kB/s eta 0:00:03
#    --------------------------------- ------ 8.9/10.6 MB 687.7 kB/s eta 0:00:03
#    --------------------------------- ------ 8.9/10.6 MB 687.7 kB/s eta 0:00:03
#    ---------------------------------- ----- 9.2/10.6 MB 689.7 kB/s eta 0:00:03
#    ------------------------------------ --- 9.7/10.6 MB 708.9 kB/s eta 0:00:02
#    ------------------------------------- -- 10.0/10.6 MB 720.1 kB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 746.9 kB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 751.7 kB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
